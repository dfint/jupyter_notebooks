# %%
from babel.messages import Catalog, pofile

# %%
source = "for_translation_dwarf-fortress-steam_hardcoded_steam_ru.po"

# %%
reference = "for_use_dwarf-fortress_hardcoded_ru.po"

# %%
output = "output.po"

# %%
with open(reference, encoding="utf-8") as reference_file:
    catalog = pofile.read_po(reference_file)
    dictionary = {
        message.id: message.string
        for message in catalog
        if message.id and message.string
    }

# %%
dictionary
# Out:
# {'General': 'Общее',
#  'World': 'Мир',
#  'Adventurer': 'Искатель приключений',
#  'Dwarf mode': 'Режим крепости',
#  'Embark': 'Высадка',
#  'Building': 'Строительство',
#  'Workshop': 'Мастерская',
#  'Pilezone': 'Склады',
#  'Stockorder': 'Управление складами',
#  'Militia': 'Ополчение',
#  'Text entry': 'Ввод текста',
#  'its': 'его',
#  'it': 'он',
#  'itself': 'себя',
#  'Activity': 'Активность',
#  'Training Session': 'Тренировка',
#  'Activity Event': 'Событие',
#  'Research': 'Исследовать',
#  'Play': 'Играть',
#  'Worship': 'Поклоняться',
#  'Socialize': 'Общаться',
#  ' empty ': ' опустошаете ',
#  ' empties ': ' опустошает ',
#  ' pick up ': ' подбираете ',
#  ' picks up ': ' подбирает ',
#  ' embraces ': ' обнимает ',
#  ' has shared many tales from beyond ': 'поделился многими рассказами из-за пределов',
#  ' has shared a few rumors.': 'поделился несколькими слухами.',
#  ' has shared a rumor from abroad.': 'поделился слухами из-за рубежа.',
#  ' gives you ': 'даёт вам',
#  ' has discovered ': 'открыл',
#  ' has become a student of ': 'стал учеником',
#  'Ponder ': 'Размышлять',
#  'Teach ': 'Учить',
#  'Learn ': 'Изучать',
#  'Discuss ': 'Обсуждать',
#  'Read': 'Читать',
#  'Write': 'Писать',
#  'Write about ': 'Писать о',
#  'Copy': 'Переписывать',
#  'Meditate on ': 'Медитировать на',
#  'Pray to ': 'Молиться',
#  'Go to Combat Training': 'Отправиться на тренировку',
#  'Organize Combat Training': 'Организовывать тренировку',
#  'Lead Combat Training': 'Вести тренировку',
#  'Wait for Combat Training': 'Ожидание тренировки',
#  'Play Make Believe': 'Играть в "изобрази"',
#  'Play with ': 'Играть с ',
#  'Toy': 'Игрушка',
#  'Listen to Sermon': 'Слушать проповедь',
#  'Preach on ': 'Проповедовать',
#  'Promote ': 'Продвигать',
#  'Inveigh Against ': 'Ополчиться против',
#  'Law': 'Закон',
#  'Loyalty': 'Верность',
#  'Family': 'Семья',
#  'Friendship': 'Дружба',
#  'Power': 'Сила',
#  'Truth': 'Истина',
#  'Cunning': 'Хитрость',
#  'Eloquence': 'Красноречие',
#  'Fairness': 'Справедливость',
#  'Decorum': 'Приличия',
#  'Tradition': 'Традиции',
#  'Artwork': 'Произведение искусства',
#  'Cooperation': 'Сотрудничество',
#  'Independence': 'Независимость',
#  'Stoicism': 'Стоицизм',
#  'Introspection': 'Самоанализ',
#  'Self-Control': 'Самоконтроль',
#  'Tranquility': 'Спокойствие',
#  'Harmony': 'Гармония',
#  'Merriment': 'Веселье',
#  'Craftsmanship': 'Мастерство',
#  'Martial Prowess': 'Боевая доблесть',
#  'Skill': 'Умение',
#  'Hard Work': 'Тяжёлый труд',
#  'Sacrifice': 'Жертвенность',
#  'Competition': 'Завершение',
#  'Perseverance': 'упорстве',
#  'Leisure Time': 'Свободное время',
#  'Commerce': 'Коммерция',
#  'Romance': 'Романтика',
#  'Nature': 'Природа',
#  'Peace': 'Мир',
#  'Knowledge': 'Знания',
#  'Listen to Story': 'Слушать историю',
#  'Tell Story': 'Рассказывать историю',
#  'Listen to Poetry': 'Слушать стихи',
#  'Listen to Music': 'Слушать музыку',
#  'Simulate ': 'Имитировать',
#  'Play ': 'Играть',
#  'Sing': 'Петь',
#  'Chant': 'Петь',
#  'Recite Poetry': 'Декламировать стихи',
#  'Perform Music': 'Играть музыку',
#  'Watch Dance': 'Наблюдать танец',
#  'Perform Dance': 'Танцевать',
#  'Go to ': 'Перейти к ',
#  ' Demonstration': ' демонстрации',
#  'Lead ': 'Вести ',
#  'Organize ': 'Организовать ',
#  'Watch ': 'Смотреть ',
#  'Wait for ': 'Ждать ',
#  'Serve ': 'Служить',
#  'Serve Customer': 'Обслуживать клиента',
#  'Go to Individual Combat Drill': 'Перейти к индивидуальной тренировке',
#  'Individual Combat Drill': 'Индивидуальная тренировка',
#  '/Resting': '/Отдых',
#  'Go to Sparring Match': 'Перейти к спаррингу',
#  'Spar': 'Спар',
#  'Go to Sparring Practice': 'Заниматься спаррингом',
#  'Watch Sparring Practice': 'Смотреть спарринг',
#  'Archery Practice': 'Тренировка стрельбы',
#  'You cannot perform here.': 'Вы не можете исполнять здесь.',
#  'You could not find a partner.': 'Вы не можете найти партнера',
#  'There are not enough dancers.': 'Здесь недостаточно танцоров',
#  'There is not enough room to perform here.': 'Здесь недостаточно места для представления.',
#  'You': 'Вы ',
#  'Some children': 'Некоторые дети',
#  'is': '-',
#  'are': '-',
#  'begins': 'начинает',
#  'begin': 'начинаете',
#  ' playing make believe.': 'играть в "изобрази".',
#  ' playing with ': 'играют с ',
#  'a toy': 'игрушкой',
#  'The performers': 'Исполнители',
#  'a sermon on ': 'проповедь о',
#  'the story of ': 'историю про ',
#  'reciting the poem ': 'читает стихи',
#  'an improvised recital of ': 'импровизированное декламирование ',
#  'the musical composition ': 'музыкальную композицию',
#  'improvised music, ': 'импровизированную композицию,',
#  'dancing ': 'танцевать',
#  'an improvised dance, ': 'импровизированный танец,',
#  ' in the middle of ': 'в середине ',
#  'You continue the sermon.': 'Вы продолжаете проповедь.',
#  'The sermon continues.': 'Проповедь продолжается.',
#  'You continue the story.': 'Вы продолжаете рассказ.',
#  'The story continues.': 'История продолжается.',
#  'You begin': 'Вы начинаете',
#  'The poetry enters': 'Стихи переходят в',
#  'the ': ' ',
#  ' line.': 'строку.',
#  'the verse paragraph': 'четверостишье',
#  ' verse paragraph': 'четверостишье',
#  'the stanza': 'строфу',
#  ' stanza': 'строфу',
#  'You continue the poem.': 'Вы продолжаете читать стихотворение.',
#  'The poem continues.': 'Стихотворение продолжается.',
#  'You continue the dance.': 'Вы продолжаете танец.',
#  'You enter ': 'Вы переходите в',
#  'The dance enters a new section with ': 'Танец переходит в очередную часть с ',
#  'The music enters ': 'Музыка переходит в',
#  'a simple passage': 'простой пассаж',
#  'the introduction': 'вступление',
#  'the exposition': 'экспозиция',
#  ' of the theme': 'темы',
#  ' of the first theme': 'первой темы',
#  ' of the previous passage': 'предыдущего пассажа',
#  'a recapitulation': 'рекапитуляция',
#  ' of the second theme': 'второй темы',
#  'the synthesis': 'синтез',
#  ' of the two themes': 'двух тем',
#  ' of previous passages': 'предыдущих пассажей',
#  'a verse': 'стих',
#  'a chorus': 'припев',
#  'the finale': 'окончание',
#  'the coda': 'кода',
#  'a bridge-passage': 'переходной пассаж',
#  'first ': 'первый ',
#  'theme': 'тема',
#  'second ': 'второй',
#  'a series of variations': 'серия вариаций',
#  ' on the theme': 'на тему',
#  ' on the first theme': 'на первую тему',
#  ' on the second theme': 'на вторую тему',
#  ' and ': ' и ',
#  'The dance continues.': 'Танец продолжается.',
#  'You continue the music.': 'Вы продолжаете играть.',
#  'The music continues.': 'Музыка продолжается.',
#  'You conclude your performance.': 'Вы завершаете выступление.',
#  'The performers are finished.': 'Исполнители завершают выступление.',
#  'Some performers finish their act.': 'Часть исполнителей закончили свои партии.',
#  ' has finished performing.': 'завершает выступление.',
#  ' concludes a performance.': 'завершает выступление.',
#  "You've learned ": 'Вы изучили',
#  'You feel like you know the basic rules of ': 'Вы чувствуете, что узнали основные правила',
#  ' now.': ' сейчас.',
#  'Your': 'Ваш',
#  "'s": ' ',
#  ' lay': 'лечь',
#  's': 's',
#  ' forth an awe-inspiring sermon for the ages!': 'внушающая благоговение проповедь!',
#  ' artfully deliver': 'художественно доставлять',
#  ' a lucid and powerful sermon.': 'ясную и мощную проповедь.',
#  ' giving a creditable sermon.': 'читая неплохую проповедь.',
#  " just can't give a sermon very well.": 'не может дать хорошую проповедь.',
#  ' weave': 'плетёте',
#  ' a mesmerizing tale!': 'завораживающую историю!',
#  ' tell': 'рассказывает',
#  ' the story in vivid detail.': 'историю в ярких красках.',
#  ' telling the tale quite well.': 'довольно неплохо рассказывая историю.',
#  ' stumble': ' спотыкаетесь',
#  ' over the details.': 'на подробностях.',
#  ' bring': 'воплощаете',
#  ' the poem to life with this flawless recitation.': 'стихи в жизнь своей безупречной декламацией.',
#  ' choose': 'выбираете',
#  ' the perfect phrasing.': 'безупречные фразы.',
#  ' recite': 'декламируете',
#  ' the words evocatively.': 'слова с выражением.',
#  ' enunciate': 'произносите',
#  ' crisply.': 'чётко.',
#  ' speak': 'проговариваете',
#  ' well.': 'хорошо.',
#  ' mumble': 'боромочете',
#  ', having completely forgotten the words.': ', чтобы вспомнить слова.',
#  ' poorly.': 'плохо.',
#  ' and the ': ' и ',
#  ' are indistinguishable!': 'неразличим!',
#  'instrument': 'инструмент',
#  ' delivering a virtuoso performance on the ': 'давая виртуозное выступление на',
#  'chant': 'напевает',
#  ' is absolutely flawless.': 'просто безупречна.',
#  'song': 'песни',
#  ' could nearly pass for the voice of the ': 'еле подходит для голоса',
#  ' play': 'играть',
#  ' the ': ' ',
#  ' with skill.': 'с умением.',
#  'sing': 'петь',
#  ' beautifully.': 'прекрасно.',
#  ' sound': 'звук',
#  ' vaguely like the intended ': 'как будто так и задумно',
#  ' playing the ': 'играет',
#  'chanting': 'пение',
#  'singing': 'поющий',
#  ' make': 'делать',
#  ' a mockery of the ': 'издевательство над ',
#  ' with a shameworthy performance.': 'позорным исполнением.',
#  "doesn't": 'не',
#  ' seem to know how to play the ': 'похоже что знает, как играть',
#  "don't": 'не',
#  ' sloppily': 'небрежно',
#  ' and even forget': 'и даже забыть',
#  ' some of the words.': 'некоторые слова.',
#  ' dance': 'танец',
#  ' flawlessly, like someone out of a legend!': 'безупречно, достойно легенд!',
#  ' dancing exceptionally.': 'танцуя потрясающе.',
#  ' dancing well.': 'неплохо танцуя.',
#  ' get': ' запутался',
#  ' tangled up.': '.',
#  'It has no writing.': 'Здесь ничего не написано.',
#  'The pages are blank.': 'Страницы пусты.',
#  'It has no pages.': 'Здесь нет страниц.',
#  'Done: ': 'Готово: ',
#  'Insurrection with ': 'Восстание с ',
#  'Guided by ': 'Под руководством',
#  'Rescue ': 'Спасение',
#  'Aid rescue with ': 'Помощь в спасении с ',
#  'Adventure with ': 'Приключение с ',
#  'The bound service of': 'Пограничная служба ',
#  'Entertain people with ': 'Развлекать народ с ',
#  'World Joining Agreement': 'Соглашение присоединения к миру',
#  'Residency Agreement': 'Соглашение о проживании',
#  'Grant of Citizenship': 'Предоставление гражданства',
#  'Parley Arrangement': 'Обсуждение обстановки',
#  'Corruption': 'Коррупция',
#  'Artifact Theft': 'Кража артефакта',
#  'Promise of Position': 'Обещать должность',
#  'Assassination Plot': 'Место убийства',
#  'Abduction Plot': 'Место похищения',
#  'Sabotage Plot': 'Место саботажа',
#  'Infiltration Plot': 'Место проникновения',
#  'Framing Plot': 'Место фермерства',
#  'War Starting Plot': 'Место начала войны',
#  'Foiled Embezzlement Conspiracy': 'Раскрытое скрытие растраты',
#  'Foiled Corruption Conspiracy': 'Раскрытое сокрытие коррупции',
#  'Foiled Bribery Conspiracy': 'Раскрытое сокрытие взятки',
#  'Build Structure': 'Строить структуру',
#  ' from ': ' из ',
#  'Unknown': 'Неизвестно',
#  'Unnamed ': 'Без имени ',
#  'dark': 'тёмный',
#  ': Scroll': ': Прокрутка',
#  ': Recenter on current location': ': Центрировать на месте события',
#  'Target location': 'Целевое место',
#  'Ask around or': 'Расспросить вокруг или',
#  'find a guide.': 'найти проводника.',
#  'Unknown location': 'Неизвестное место',
#  ': View full map': ': Показать полную карту',
#  ': Collapse': ': Свернуть',
#  ': Expand': ': Расширить',
#  ': Recenter on location': ': Центрировать на месте',
#  ': Recenter on last heard': ': Центрировать на последнем услышанном',
#  ': Recenter on first heard': ': Центрировать на первом услышанном',
#  ': Showing type,date': ': Показывать тип, дату',
#  ': Showing pin,last': ': Показывать закрепленное, последнее',
#  ': Unpin event': ': Открепить событие',
#  ': Pin event': ': Закрепить событие',
#  'Overthrow Agreement': 'Соглашение о перевороте',
#  'Guide Agreement': 'Соглашение с проводником',
#  'Rescue Agreement': 'Соглашение о спасении',
#  'Aid Rescue Agreement': 'Соглашение о помощи в спасении',
#  'Adventuring Agreement': 'Соглашение о странствиях',
#  'Bound Servitude': 'Сверхъестественное служение',
#  'Entertainment Agreement': 'Соглашение о развлечениях',
#  'agreed to join': 'согласился присоединиться',
#  'you': 'вас',
#  'in insurrection against': 'в восстании против',
#  'thereby freeing': 'таким образом освобождая',
#  'agreed to guide': 'согласился проводить',
#  'to': 'в',
#  'somebody unknown': 'кто-то неизвестный',
#  'in order to be brought safely away from': ', чтобы безопасно увести из',
#  'in order to rescue': ', чтобы спасти',
#  'agreed to adventure with': 'согласился путешествовать с ',
#  'wherever the journey might lead': ', куда бы не привела дорога',
#  'was bound to serve': 'был заставлен служить',
#  'by invocation of True Name': 'воззванием по Истинному имени',
#  'agreed to entertain people with': 'согласился развлекать людей',
#  'throughout the world': 'по всему миру',
#  'Agreement concluded': 'Соглашение заключено',
#  'st': 'ое',
#  'nd': 'ое',
#  'rd': 'е ',
#  'th': 'ое',
#  'Kill': 'Убить',
#  'Drive members of': 'Прогнать членов ',
#  'out of': 'из ',
#  'Drive': 'Вести',
#  'from': 'от',
#  'Cause trouble for': 'Создаёт проблемы для',
#  'An order from': 'Приказ от ',
#  'Finish reporting in': 'Завершить, предоставив отчёт в ',
#  'Complete: report back': 'Завершено: отчитаться',
#  'Not yet completed': 'Ещё не завершено',
#  ': Recenter on target': ': Центрировать на цели',
#  ': Recenter on commander': ': Центрировать на командире',
#  'Org: ': 'Орг:',
#  'One member': 'Один член',
#  ' members': 'члены',
#  ': Select': ': Выбор',
#  ': View Chart': ': Просмотр схемы',
#  ': Showing important': ': Показать важное',
#  ': Showing all': ': Показать всё',
#  'Events': 'События',
#  'Agreements': 'Соглашения',
#  'People': 'Люди',
#  'Sites': 'Места',
#  'Groups': 'Группы',
#  'Regions': 'Регионы',
#  'Bestiary': 'Бестиарий',
#  'Artifacts': 'Артефакты',
#  'Intrigue': 'Интрига',
#  ' Actors': 'Актеры',
#  'Organizations': 'Организации',
#  'Plots': 'Точки',
#  ': Toggle line': ': Переключить строку',
#  ': Filter on ': ': Фильтр вкл.',
#  ': Filter': ': Фильтр',
#  ': Filter on _': ': Фильтр вкл _',
#  'This site is the capital of ': 'Это место - столица ',
#  'This site is a fortress of ': 'Это место - крепость ',
#  'This site is controlled by ': 'Это место контролируется ',
#  'Civilization': 'Цивилизация',
#  'Site Government': 'Правительство области',
#  'Vessel Crew': 'Экипаж судна',
#  'Migrating Group': 'Мигрирующая группа',
#  'Nomadic Group': 'Кочующая группа',
#  'Religion': 'Религия',
#  'Military Organization': 'Военная организация',
#  'Outcast': 'Изгнанник',
#  'Performance Troupe': 'Труппа',
#  'Merchant Company': 'Торговая компания',
#  'Craft Guild': 'Ремесленная гильдия',
#  ', Dead': ', мёртвый',
#  'Enemy': 'Враг',
#  'Criminal': 'Преступник',
#  'Prisoner': 'Заключённый',
#  'Former ': 'Бывший ',
#  'member': 'член',
#  'mercenary': 'наёмник',
#  'slave': 'раб',
#  'prisoner': 'заключённый',
#  'Devoted': 'Посвящённый',
#  'Loyal': 'Верный',
#  'Aligned': 'Равный',
#  'Affiliated': 'Подчинённый',
#  'Associated': 'Связанный',
#  ' member': ' член',
#  ' mercenary': ' наёмник',
#  ' slave': ' раб',
#  'Mountain': 'Гора',
#  'Glacier': 'Ледник',
#  'Tundra': 'Тундра',
#  'Temperate Freshwater Swamp': 'Умеренные пресные болота',
#  'Temperate Saltwater Swamp': 'Умеренные солёные болота',
#  'Temperate Freshwater Marsh': 'Умеренные пресные топи',
#  'Temperate Saltwater Marsh': 'Умеренные солёные топи',
#  'Tropical Freshwater Swamp': 'Тропические пресные болота',
#  'Tropical Saltwater Swamp': 'Тропические солёные болота',
#  'Mangrove Swamp': 'Мангровые болота',
#  'Tropical Freshwater Marsh': 'Тропические пресные топи',
#  'Tropical Saltwater Marsh': 'Тропические солёные топи',
#  'Taiga': 'Тайга',
#  'Temperate Coniferous Forest': 'Умеренные хвойные леса',
#  'Temperate Broadleaf Forest': 'Умеренные лиственные леса',
#  'Tropical Coniferous Forest': 'Тропические хвойные леса',
#  'Tropical Dry Broadleaf Forest': 'Тропические сухие лиственные леса',
#  'Tropical Moist Broadleaf Forest': 'Влажные тропические лиственные леса',
#  'Temperate Grassland': 'Умеренные луга',
#  'Temperate Savanna': 'Умеренная саванна',
#  'Temperate Shrubland': 'Умеренные кустарники',
#  'Tropical Grassland': 'Тропические луга',
#  'Tropical Savanna': 'Тропическая саванна',
#  'Tropical Shrubland': 'Тропические кустарники',
#  'Badlands': 'Пустоши',
#  'Rocky Wasteland': 'Каменистая пустыня',
#  'Sand Desert': 'Песчаная пустыня',
#  'Tropical Ocean': 'Тропический океан',
#  'Temperate Ocean': 'Умеренный океан',
#  'Arctic Ocean': 'Арктический океан',
#  'Temperate Freshwater Pool': 'Умеренный пресный водоём',
#  'Temperate Brackish Pool': 'Умеренный солоноватый водоём',
#  'Temperate Saltwater Pool': 'Умеренный солёный водоём',
#  'Tropical Freshwater Pool': 'Тропический пресный водоём',
#  'Tropical Brackish Pool': 'Тропический солоноватой водоём',
#  'Tropical Saltwater Pool': 'Тропический солёный водоём',
#  'Temperate Freshwater Lake': 'Умеренное пресное озеро',
#  'Temperate Brackish Lake': 'Умеренное солоноватое озеро',
#  'Temperate Saltwater Lake': 'Умеренное солёное озеро',
#  'Tropical Freshwater Lake': 'Тропическое пресное озеро',
#  'Tropical Brackish Lake': 'Тропическое солоноватое озеро',
#  'Tropical Saltwater Lake': 'Тропическое солёное озеро',
#  'Temperate Freshwater River': 'Умеренная пресная река',
#  'Temperate Brackish River': 'Умеренная солоноватая река',
#  'Temperate Saltwater River': 'Умеренная солёная река',
#  'Tropical Freshwater River': 'Тропическая пресная река',
#  'Tropical Brackish River': 'Тропическая солоноватая река',
#  'Tropical Saltwater River': 'Тропическая солёная река',
#  'Subterranean Water': 'Подземные воды',
#  'Subterranean Chasm': 'Подземная пропасть',
#  'Subterranean Magma': 'Подземная магма',
#  'It is traditionally thought to be ': 'Традиционно считается',
#  'It was last seen ': 'Это было в последний раз',
#  'It was last rumored to be ': 'по последним слухам',
#  'held by ': 'принадлежит ',
#  ' in ': ' в ',
#  'in ': 'в ',
#  'Alias: ': 'Псевдоним:',
#  'Highest known in organization': 'Высший известный в организации',
#  'Associated Organization: ': 'Связанная организация:',
#  'Associated Plot: ': 'Связанное место:',
#  'Died in the year ': 'Умер в ',
#  ' deity': ' божество',
#  'This person is one of the ': 'Это один из ',
#  ' of ': ' ',
#  ' and your military subordinate': ' и ваш военный подчинённый',
#  'Force': 'Сила',
#  ' alongside you': ' вместе с вами',
#  'This person is ': 'Это ',
#  ' and your military commander': ' и ваш военный командир',
#  'You last spoke ': 'Вы в последний раз разговаривали ',
#  'You have known this person your entire life.': 'Вы знаете эту личность всю свою жизнь.',
#  'You have known this person since ': 'Вы знаете эту личность с ',
#  'his': 'его',
#  'her': 'её ',
#  ' birth.': ' рождения.',
#  'You have known each other your entire lives.': 'Вы знаете друг друга всю жизнь.',
#  'You have heard this name suggested as a potential guide to faraway places.': 'Вы слышали, что он может быть проводником в дальних краях.',
#  'You worship this figure.': 'Вы боготворите эту личность.',
#  'This is your lover.': 'Это ваш любовник.',
#  'This is your prisoner.': 'Это ваш узник.',
#  'This is your jailor.': 'Это ваш тюремщик.',
#  'This is your master.': 'Это ваш учитель.',
#  'This is your apprentice.': 'Это ваш ученик.',
#  'This is your traveling companion.': 'Это ваш спутник.',
#  'This is your former master.': 'Это ваш бывший хозяин.',
#  'This is your former apprentice.': 'Это ваш бывший ученик.',
#  'This is your owner.': 'Это ваш владелец.',
#  'This is your former spouse.': 'Это ваш бывший супруг/супруга.',
#  'This is your deceased spouse.': 'Это ваш умерший супруг/супруга.',
#  'This is your ': 'Это ваш ',
#  'You have recently encountered one of these creatures.': 'Вы недавно сталкивались с одним из этих существ.',
#  'You have encountered these creatures in the past but not recently.': 'Вы встречали таких существ, но довольно давно.',
#  'You have only heard tell of these creatures.': 'Вы только слышали о таких существах.',
#  'You have killed ': 'Вы убили ',
#  ' of these creatures.': ' этих существ.',
#  'This creature can be found in ': 'Это существо можно встретить в ',
#  'This creature lives in ': 'Это существо живёт в ',
#  'This creature dwells underground.': 'Это подземное существо.',
#  'This event occurred on the ': 'Это событие произошло в ',
#  ' in the year ': ' в ',
#  'Somebody': 'кого-то',
#  ' giving of ': 'подношение',
#  ' placement of ': 'размещение',
#  'an untitled work': 'безымянная работа',
#  ' to ': ' ',
#  'somebody': 'кем-то',
#  'The destruction of': 'Разрушение ',
#  ' gaining of ': 'получение',
#  ' possession of ': 'владение',
#  ' refusal to give ': 'отказался передать',
#  'The reunion of ': 'Воссоединение ',
#  'Your reunion with ': 'Ваше воссоединение с ',
#  'Your death': 'Ваша смерть ',
#  'The death of ': 'Смерть ',
#  'A ': ' ',
#  'production order violation': 'нарушение приказа о производстве',
#  'export prohibition violation': 'нарушение запрета на экспорт',
#  'job order violation': 'нарушение приказа о работе',
#  'conspiracy to slow labor': 'сокрытие медленной работы',
#  'crime of murder': 'убийство',
#  'disorderly conduct': 'хулиганство',
#  'building destruction': 'разрушение строения',
#  'bribery': 'взятка',
#  'embezzlement': 'растрата',
#  'vandalism': 'вандализм',
#  'crime of theft': 'кража',
#  'crime of robbery': 'грабёж',
#  'crime of espionage': 'шпионаж',
#  'crime of treason': 'измена',
#  'crime of blood-drinking': 'вампиризм',
#  'crime of attempted theft': 'попытка кражи',
#  'crime of attempted murder': 'покушение на убийство',
#  'crime of kidnapping': 'похищение',
#  'crime of attempted kidnapping': 'попытка похищения',
#  ' self-identification to ': 'рассказ о себе',
#  ' refusal to identify to ': 'отказ представиться ',
#  ' demand of submission from ': ' требование покорности с ',
#  ' attack on ': ' нападение на ',
#  ' escalated attack on ': ' провоцировал атаку на ',
#  ' ascension': ' повышение',
#  ' presence': ' присутствие',
#  "'s presence": ' присутствие',
#  "'s acceptance of ": 'принятие ',
#  "'s offer of tribute": ' предложение дани',
#  "'s refusal of ": ' отказ от ',
#  "'s demand for tribute": ' требование дани',
#  "'s offer of peace": ' предложение мира',
#  "'s cessation of tribute to ": ' прекращение выплаты дани ',
#  "'s claim": ' претензии',
#  ' on ': ' на ',
#  "'s harassment": ' притеснение',
#  "'s withdrawal from ": ' выводе войск из ',
#  "'s flight": ' полёт',
#  "'s abandonment": ' покидание',
#  'The insurrection': 'Восстание',
#  ' against ': ' против ',
#  'The ': ' ',
#  'insurrection crushed': 'восстание подавлено',
#  ' by ': ' ',
#  'failed insurrection ': 'не удалось восстание ',
#  'overthrow ': 'свержение ',
#  "'s reclamation": ' возвращение',
#  "'s foundation": ' основание',
#  "'s march": ' марш',
#  ' to reclaim ': ' вернуть ',
#  ' to found a site in ': ' найти место в ',
#  ' toward ': ' вперёд ',
#  'The occupation of ': 'Оккупация ',
#  'Your abduction': 'Ваше похищение',
#  'The abduction of ': 'Похищение ',
#  'The destruction of ': 'Уничтожение',
#  'The presence of ': 'Присутствие',
#  'Your possession of ': 'Ваше владение',
#  "'s possession of ": 'владение',
#  'The absence of ': 'Отсутствие',
#  "'s ": ' ',
#  'Your lack of possession of ': 'Ваша утрата владения',
#  "'s lack of possession of ": 'утрата владения',
#  'You have been ordered to slay this creature.': 'Вам приказано убить это существо.',
#  'You have been ordered to drive these forces out.': 'Вам приказано изгнать эти войска.',
#  'You have been ordered to clear the forces from this site.': 'Вам приказано изгнать войска с этого места.',
#  'You have been ordered to cause trouble for these forces.': 'Вам приказано создать неприятности для этих войск.',
#  'You last': 'Ваш последний',
#  ' heard this ': ' слышал это ',
#  'on the ': 'на ',
#  'You first heard this ': 'Вы впервые услышали это ',
#  'This is common knowledge where you are from.': 'Там, откуда вы родом, это общеизвестно.',
#  'writing': 'письменность',
#  'Writing': 'Текст написан',
#  ' Given': 'Дано',
#  ' Dropped': 'Уронил',
#  'me': 'мне',
#  '/You': '/Вы',
#  ' you': 'вы',
#  'artifact': 'артефакт',
#  'Artifact': 'Артефакт',
#  ' Destroyed': 'Уничтожен ',
#  ' Held': 'Провели',
#  ' Gained': 'Приобретенный',
#  ' Denied': 'Отказано',
#  'rescue': 'спасение',
#  'reunion': 'воссоединение',
#  'reunited': 'воссоединённый',
#  'Reunion': 'Воссоединение',
#  'Reunion/': 'Воссоединение/',
#  'death': 'смертью',
#  'Death/You': 'Смерть/вы',
#  'Death/': 'Смерть/',
#  'crime': 'преступление',
#  'production': 'производство',
#  'order': 'приказами',
#  'violation': 'нарушение',
#  'export': 'экспорт',
#  'prohibition': 'запрет',
#  'job': 'работа',
#  'conspiracy': 'сокрытие',
#  'slow': 'медленно',
#  'labor': 'трудом',
#  'Murder': 'Убийство',
#  'murder': 'убийством',
#  'Disorder': 'Хулиганство',
#  'disorderly': 'беспорядочное',
#  'conduct': 'поведение',
#  'building': 'строение',
#  'destruction': 'разрушение',
#  'Bribery': 'Взятка',
#  'Embezzlement': 'Растрата',
#  'Vandalism': 'Вандализм',
#  'Theft': 'Кража',
#  'theft': 'кража',
#  'Robbery': 'Грабёж',
#  'robbery': 'ограбление',
#  'Espionage': 'Шпионаж',
#  'espionage': 'шпионаж',
#  'Treason': 'Измена',
#  'treason': 'измена',
#  'Blood-drinking': 'Вампиризм',
#  'blood': 'кровь',
#  'drinking': 'питьё',
#  'kidnapping': 'похищение',
#  'snatching': 'похищение',
#  'performance': 'представление',
#  'Performance': 'Выступление',
#  'Sermon/': 'Проповедь/',
#  'Performance/': 'Выступление/',
#  'a poem': 'стихи',
#  'music': 'музыка',
#  'dance': 'танец',
#  'give': 'давать',
#  'name': 'имя',
#  'identity': 'личность',
#  'refuse': 'отказаться',
#  'demand': 'требование',
#  'submission': 'покорность',
#  'fight': 'бой',
#  'conflict': 'конфликт',
#  'Attack/': 'Атака/',
#  'Escalation/': 'Ухудшение/',
#  'succession': 'наследование',
#  'leader': 'лидер',
#  'presence': 'присутствие',
#  'Beast/': 'Чудовище/',
#  'Group/': 'Группа/',
#  'tribute': 'дань',
#  'Tribute/': 'Дань/',
#  'peace': 'покоем',
#  'Peace/': 'Мир/',
#  'claim': 'требование',
#  'harassment': 'беспокойство',
#  'Harass/': 'Беспокойство/',
#  'withdrawal': 'выводе войск',
#  'Leave/': 'Оставить/',
#  'refugees': 'беженцы',
#  'flight': 'полёт',
#  'Flee/': 'Бежать/',
#  'Abandon/': 'Покинуть/',
#  'insurrection': 'восстание',
#  'Insurrection': 'Восстание',
#  'crushed': 'раздавлены',
#  'defeat': 'поражение',
#  'Crushed': 'Сокрушённый',
#  'failure': 'неудача',
#  'Failed': 'Проваленный',
#  'overthrow': 'свержение',
#  'revolution': 'революция',
#  'Overthrow': 'Свержение',
#  'reclaim': 'вернуть',
#  'Reclaimed/': 'Возвращённый/',
#  'founding': 'основание',
#  'Founded/': 'Основанный/',
#  'Reclaiming/': 'Возвращение/',
#  'Founding/': 'Основание/',
#  'army': 'армия',
#  'march': 'марш',
#  'invasion': 'вторжение',
#  'Invasion/': 'Вторжение/',
#  'occupation': 'оккупация',
#  'Occupation/': 'Занятие/',
#  'abduction': 'похищение',
#  'kidnap': 'похитить',
#  'Abduction/You': 'Похищение/Вы',
#  'Abduction/': 'Похищение/',
#  'Artifact/': 'Artifact/',
#  'location': 'место',
#  'No Artifact/': 'No Artifact/',
#  'We should have made it there by now.': 'Мы уже должны быть там.',
#  'We should be making better progress.': 'Мы должны двигаться быстрее.',
#  'We are going the wrong way.': 'Мы движемся не в ту сторону.',
#  "We haven't performed for some time.": 'Мы не давали представлений какое-то время.',
#  'We have arrived at our destination.': 'Мы прибыли на место.',
#  'The oppressor has been overthrown!': 'Угнетатель свергнут!',
#  'We must not abandon ': 'Мы не должны бросать ',
#  'We must go back.': 'Нам нужно вернуться.',
#  'Empty announcement ': 'Empty announcement ',
#  'spinning ': 'крутящимся ',
#  'flying ': 'летящий ',
#  'It': 'Он',
#  'he': 'он',
#  'she': 'она',
#  ', but it is deflected by ': ', но был отражён ',
#  ' by the ': ' за ',
#  ' in the ': ' в ',
#  ' from behind': ' сзади',
#  ' from the side': ' со стороны ',
#  ' with ': ' с помощью ',
#  ', but the attack is deflected by ': ', но атака отражена ',
#  ', lightly tapping the target!': ', слегка задев цель!',
#  ', but there is no force!': ', но не возымела силы!',
#  ', but it passes right through!': ', но проходит мимо!',
#  ', but the attack passes right through!': ', но атака проходит мимо!',
#  ', but it glances away!': ', но соскальзывает!',
#  ', but the attack glances away!': ', но атака соскальзывает!',
#  ' and the severed part sails off in an arc!': ' и отрубленная часть тела улетает по дуге!',
#  'the part': 'часть',
#  ' is smashed into the body, an unrecognizable mass!': ' врезается в тело с нераспознаваемой массой!',
#  ' splits in gore!': ' рассыпается в фарш!',
#  ' collapses!': ' разрушается!',
#  'the injured part': 'повреждённая часть',
#  ' is ripped into loose shreds!': ' разорвана в клочья!',
#  ' is torn apart!': ' разорвана на части!',
#  ' and it is mostly cut away from the rest of the torso!': ' и почти отсечена от тела!',
#  ' is cloven asunder!': ' разрублена пополам!',
#  ' explodes into gore!': ' превращается в фарш!',
#  ' collapses into a lump of gore!': ' превращается в кучу фарша!',
#  ' is crushed!': ' раздроблена!',
#  'The geldables have been torn away!': 'Причандалы были оторваны!',
#  'tearing': 'разрывая ',
#  'tearing apart': 'разрывая на части ',
#  'shattering': 'разбивая ',
#  'chipping': 'разрубая ',
#  'fracturing': 'ломая ',
#  'denting': 'прокусывая ',
#  'bruising': 'повреждая ',
#  ' it': ' её',
#  ' apart': ' на части',
#  ' and': ' и',
#  ' tearing apart': ' разрывая на части ',
#  ' shattering': ' разбивая ',
#  ' tearing': ' разрывая ',
#  ' chipping': ' разрубая ',
#  ' fracturing': ' ломая ',
#  ' denting': ' прокусывая ',
#  ' bruising': ' повреждая ',
#  'main part': 'большая часть',
#  'passing through a hole in the ': 'проходит сквозь дыру в ',
#  'jamming the': 'сжимая ',
#  ' part': ' часть',
#  'through the ': 'сквозь ',
#  'out of the wound': 'из раны',
#  'breaking away': 'отрывая ',
#  ' most of': ' большую часть ',
#  ' half of': ' половину ',
#  ' a piece of': ' часть ',
#  ' the rest of': ' оставшуюся часть ',
#  ' through a hole in the ': ' сквозь дыру в ',
#  ' through the ': ' сквозь ',
#  ' and spilling ': ' и разливая ',
#  'your': 'ваш',
#  'fetid': 'зловонный',
#  'rotten': 'гнилой',
#  'decomposing': 'разлагающийся',
#  'rancid': 'протухший',
#  'stinking': 'вонючий',
#  'filthy': 'грязный',
#  'reeking': 'затхлый',
#  'foul': 'грязный',
#  'It is a gelding strike!': 'Это кастрирующий удар!',
#  'It is a gelding blow!': 'Это кастрирующий удар!',
#  'a major artery': 'крупная артерия',
#  'an artery': 'артерия',
#  ' has been opened by the attack': ' был вскрыт при атаке',
#  'many nerves': 'много нервов',
#  'a motor nerve': 'моторный нерв',
#  'a sensory nerve': 'сенсорный нерв',
#  'have': 'было',
#  'has': 'был',
#  ' been severed': ' отсечён',
#  'a ligament': 'связка',
#  ' has been ': ' был ',
#  'torn': 'разорван',
#  'sprained': 'растянут',
#  'bruised': 'ушиблен',
#  'a tendon': 'сухожилие',
#  'strained': 'растянуто',
#  ' is ripped to shreds!': 'разорван в клочья!',
#  ' breaks!': 'прорыв!',
#  ' attack is interrupted!': ' атака прервана!',
#  ' have': ' имеете',
#  ' has': ' имеет',
#  ' become enraged!': ' пришёл в ярость!',
#  ' has lodged firmly in the wound!': ' крепко застрял в ране!',
#  ' latch on firmly': ' крепко держитесь',
#  ' latches on firmly': ' крепко держится',
#  ' latch on firmly!': ' крепко держитесь!',
#  ' latches on firmly!': ' крепко держится!',
#  ' are': ' ',
#  ' is': ' ',
#  ' propelled away by the force of the blow!': ' отброшен силой удара!',
#  ' been knocked unconscious!': ' упал без сознания!',
#  ' been stunned again!': ' снова оглушён!',
#  ' been stunned!': ' оглушён!',
#  ' having more trouble breathing!': ' задыхается!',
#  ' having trouble breathing!': ' дышит с трудом!',
#  ' feel': ' чувствуете себя',
#  ' looks': ' выглядит',
#  ' even more sick!': ' ещё хуже!',
#  ' sick!': ' плохо!',
#  ' is injected into the ': ' вводится в ',
#  ' crumbles over the ': ' рассыпается по ',
#  ' splatters over the ': ' разбрызгивается по ',
#  ' flows over the ': ' течёт по ',
#  ' pours over the ': ' льётся на ',
#  ' is sucked out of the wound!': ' высосан из раны!',
#  'Press ': 'Нажмите ',
#  ' for more': ' для большего',
#  ' to close window': ' чтобы закрыть окно',
#  'item': 'предмет',
#  ' have returned.': 'вернулись.',
#  ' and others have returned.': 'и другие вернулись.',
#  ' has returned.': 'вернулся.',
#  ' has brought back many tales from beyond ': 'принес много историй из-за пределов',
#  ' has brought back a few rumors.': 'привёз несколько слухов.',
#  ' has brought back a rumor from abroad.': 'принёс слух из-за рубежа.',
#  ' has arrived.': ' прибыл.',
#  ' is visiting.': 'прибыл.',
#  ', the performance troupe, has arrived.': ', актерская труппа, прибыла.',
#  ', a performance troupe, is visiting.': 'труппа прибыла.',
#  'Spoils Report: ': 'Сообщение о добыче:',
#  ' and others': ' и другие',
#  'Spring': 'весны',
#  'Summer': 'лета',
#  'Autumn': 'осени',
#  'Winter': 'зимы',
#  'The dead walk.  Hide while you still can!': 'Мёртвые идут!  Спасайся кто может!',
#  'Forms twisted from their nature, legion of the night.  What hope remains?': 'Формы извращенной природы, легионы ночи. Какая надежда нам остается?',
#  'A vile force of darkness has arrived, seeking a parley!': 'Мерзкая сила тьмы пришла, ищет переговоров!',
#  'The enemy have come and are preparing to lay siege.  They seek a parley!': 'Враг пришел и готовится к осаде. Они ищут переговоров!',
#  'An army has come to your lands seeking a parley.': 'Армия вторглась в ваши земли для переговоров',
#  'A vile force of darkness has arrived!': 'Силы зла наступают!',
#  'The enemy have come and are laying siege to the fortress.': 'Враг прибыл и осадил крепость.',
#  'An army is invading!': 'Армия вторгается!',
#  'army is located out of bounds: teleporting': 'army is located out of bounds: teleporting',
#  'overlord': 'повелитель',
#  'overlords': 'повелители',
#  ' has been founded ': 'найден',
#  ', has been conquered and': ', была завоёвана, и',
#  ', has been': 'был',
#  ' incorporated into your holdings.': 'присоединенный к вашим владениям',
#  ' has been conquered and now': ', была завоёвана, и теперь',
#  ' looks to your thriving economy for its future prosperity.': ' рассчитывает на вашу преуспевающую экономику для её будущего процветания.',
#  ' is ': ' ',
#  ' are ': ' ',
#  'prostrating ': 'преклоняется',
#  'themselves': 'себя',
#  ' before ': ' перед ',
#  'torturing ': 'пытает ',
#  'committing a depraved act upon ': 'совершает развратные действия над ',
#  'devouring ': 'пожирает ',
#  'admiring ': 'восхищается ',
#  'burning ': 'горит ',
#  'shooting ': 'стреляет ',
#  'surrounded by ': 'окружён ',
#  'massacring ': 'устраивает бойню ',
#  'fighting with ': 'сражается с ',
#  'greeting ': 'приветствует ',
#  'refusing ': 'отказывается ',
#  'speaking with ': 'разговаривает с ',
#  'embracing ': 'обнимает ',
#  'striking down ': 'поражает ',
#  'raising ': 'поднимает ',
#  'hiding ': 'скрывает ',
#  'praying to ': 'молится ',
#  'contemplating ': 'размышляет о ',
#  'cooking ': 'готовит ',
#  'engraving ': 'гравирует ',
#  'impaled on ': 'насажен на ',
#  'being flayed by ': 'освежёван ',
#  'hanging from ': 'висит на ',
#  'being mutilated by ': 'покалечен ',
#  'praying': 'молится',
#  'weeping': 'плачет',
#  'cringing': 'съёживается',
#  'screaming': 'кричащий',
#  'being tortured': 'подвергается пыткам',
#  'committing a depraved act': 'совершает развратные действия',
#  'making a submissive gesture': 'выражает покорность',
#  'in a fetal position': 'в позе эмбриона',
#  'smeared out into a spiral': 'скручен в спираль',
#  'falling': 'падающий',
#  'dead': 'мёртв',
#  'laughing': 'смеётся',
#  'being shot': 'подстрелен',
#  'making a plaintive gesture': 'делает жалобный жест',
#  'melting': 'плавится',
#  'burning': 'горит',
#  'looks': 'выглядит',
#  ' dejected': ' удручённым',
#  'look': 'выглядят',
#  ' terrified': ' напуганным',
#  ' offended': ' обиженым',
#  ' confused': ' смущённым',
#  'suffering': 'страдает',
#  'withering away': ' угасает',
#  'striking a menacing pose': ' принимает угрожающую позу',
#  'striking a triumphant pose': ' принимает позу триумфатора',
#  'laboring': 'трудолюбивый',
#  'traveling': 'странствующий',
#  'contemplating': 'размышляет',
#  'cooking': ' готовит',
#  'engraving': ' гравирует',
#  'unnaturally contorted': ' неестественно вывернут',
#  'being flayed': ' освежёван',
#  'being mutilated': ' изуродован',
#  'Untitled': 'Безымянный',
#  ', the deity of ': ', божество ',
#  ', depicted as a ': ', изображается как ',
#  'skeletal ': 'скелет ',
#  'rotting ': 'гниющий ',
#  'ghostly ': 'призрачный ',
#  'female ': 'женский ',
#  'male ': 'мужской ',
#  'the deity of ': 'божество ',
#  'Seed text': 'Текст зерна',
#  'humanoid': 'гуманоид',
#  'lord': 'лорд',
#  'lords': 'лорды',
#  'lady': 'леди',
#  'ladies': 'леди',
#  'lord consort': 'лорд-консорт',
#  'lords consort': 'лорды-консорты',
#  'lady consort': 'леди-консорт',
#  'ladies consort': 'леди-консорты',
#  'hearthperson': 'доверенное лицо',
#  'hearthpeople': 'доверенные лица',
#  '  Locations  ': 'Общественные места',
#  'You have not designated any locations.': 'Вы не разметили ни одного общественного места',
#  'Locations such as taverns, temples and libraries can be created from meeting': 'Такие места как таверны, храмы и библиотеки могут быть созданы из',
#  'area zones, dining rooms and bedrooms.  These larger associations of rooms': 'мест встречи, столовых и спален. Крупные объединения комнат',
#  'can attract visitors from outside the fortress.  Once you have created a': 'могут привлекать посетителей извне крепости. Как только вы назначите место,',
#  'location, you can come to this screen to manage occupations and more.': 'вы можете перейти на этот экран для управления жильцами и прочим.',
#  ': Go Back': ': Назад',
#  'Tavern Keeper': 'Держатель таверны',
#  'Performer': 'Исполнитель',
#  'Scholar': 'Учёный',
#  'Scribe': 'Писец',
#  'Mercenary': 'Наёмник',
#  'Monster Slayer': 'Убийца монстров',
#  'Messenger': 'Вестник',
#  'Nobody': 'Никто',
#  'Tavern': 'Таверна',
#  'Boxes/bags in common area: ': 'Количество ящиков/мешков в общей зоне:',
#  'Goblets (Desired): ': 'Кружки (требуется):',
#  'Stored Instruments (Desired): ': 'Хранимые музыкальные инструменты (требуется):',
#  'Rented rooms (Total): ': 'Комнаты для постояльцев (итого):',
#  'Dance floor in common area: ': 'Общая площадь для танцев:',
#  'None': 'Нет',
#  'Library': 'Библиотека',
#  'Bookcases: ': 'Книжные шкафы:',
#  'Written objects (incl. copies): ': 'Тексты (включая копии):',
#  'Total number of each to scribe: ': 'Общее количество каждого для переписывания: ',
#  'Writing Material (Desired): ': 'Писчий материал (требуется):',
#  'Tables: ': 'Столы: ',
#  'Chairs: ': 'Стулья:',
#  'Temple': 'Храм',
#  'Dedicated to ': 'Посвящается  ',
#  'No particular deity': 'Нет конкретного божества',
#  'Temple Complex, ': 'Храмовый комплекс,',
#  'Temple, ': 'Храм,',
#  ' (next at ': '(следующий в',
#  'Shrine, ': 'Святыня,',
#  'Priest: ': 'Священник:',
#  'High priest: ': 'Первосвященник:',
#  ' worshipper': 'поклонник',
#  ' needed': 'требуется',
#  ': Recognize priesthood': ': Признать священство',
#  ': Recognize high priest': ': Признать первосвященником',
#  'Agreed to build temple': 'Согласиться построить храм',
#  'Agreed to build temple complex': 'Согласиться построить храмовый комплекс',
#  ' Guildhall': 'Зал гильдии',
#  'No members': 'Нет членов',
#  'No established guild': 'Нет основанной гильдии',
#  ' worker': 'работник',
#  'No workers': 'Нет работников',
#  'Grand Guildhall, ': 'Большой зал гильдии,',
#  'Guildhall, ': 'Зал гильдии,',
#  'Meeting place, ': 'Место встречи,',
#  ...}

# %%
with open(source, encoding="utf-8") as source_file:
    source_catalog = pofile.read_po(source_file)
    output_catalog = Catalog()
    for message in source_catalog:
        translation = message.string or dictionary.get(message.id)

        output_catalog.add(
            id=message.id,
            string=translation,
            locations=message.locations,
            flags=message.flags,
            auto_comments=message.auto_comments,
            user_comments=message.user_comments,
            previous_id=message.previous_id,
            lineno=message.lineno,
            context=message.context,
        )

# %%
with open(output, "wb") as output_file:
    pofile.write_po(output_file, output_catalog)
